# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-gupta98/supermarket_grocery_sales/blob/main/src/Supermarket_grocery_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('/content/Supermart Grocery Sales - Retail Analytics Dataset.csv')

# %%
data.head()
# Out:
#   Order ID Customer Name          Category      Sub Category         City  \
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1  11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2  06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3  10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4  10-11-2016  South   2355      0.26  918.45  Tamil Nadu

# %%
data.shape
# Out:
# (9994, 11)

# %%
data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
data.isnull().sum()
# Out:
# Order ID         0
# Customer Name    0
# Category         0
# Sub Category     0
# City             0
# Order Date       0
# Region           0
# Sales            0
# Discount         0
# Profit           0
# State            0
# dtype: int64

# %%
data['State'].unique()
# Out:
# array(['Tamil Nadu'], dtype=object)

# %%
round(data['Sales'].mean(),2)
# Out:
# 1496.6

# %%
data['Region'].unique()
# Out:
# array(['North', 'South', 'West', 'Central', 'East'], dtype=object)

# %%
data['City'].unique()
# Out:
# array(['Vellore', 'Krishnagiri', 'Perambalur', 'Dharmapuri', 'Ooty',
#        'Trichy', 'Ramanadhapuram', 'Tirunelveli', 'Chennai', 'Karur',
#        'Namakkal', 'Dindigul', 'Kanyakumari', 'Bodi', 'Tenkasi',
#        'Viluppuram', 'Madurai', 'Salem', 'Cumbum', 'Nagercoil',
#        'Pudukottai', 'Theni', 'Coimbatore', 'Virudhunagar'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
city_wise_sales_mean = round(data.groupby('City')['Sales'].mean(),2)
city_wise_sales_mean
# Out:
# City
# Bodi              1509.45
# Chennai           1469.82
# Coimbatore        1483.06
# Cumbum            1501.31
# Dharmapuri        1520.09
# Dindigul          1453.61
# Kanyakumari       1539.79
# Karur             1493.66
# Krishnagiri       1448.35
# Madurai           1514.30
# Nagercoil         1478.38
# Namakkal          1485.19
# Ooty              1483.40
# Perambalur        1520.13
# Pudukottai        1519.02
# Ramanadhapuram    1506.86
# Salem             1524.58
# Tenkasi           1489.94
# Theni             1497.55
# Tirunelveli       1479.40
# Trichy            1516.54
# Vellore           1555.29
# Viluppuram        1464.17
# Virudhunagar      1458.70
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=city_wise_sales_mean.values, y=city_wise_sales_mean.index, palette=sns.color_palette())
plt.title("City wise sales mean")
plt.xlabel("Sales mean")
plt.ylabel("City")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-942c5080b9b8>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_wise_sales_mean.values, y=city_wise_sales_mean.index, palette=sns.color_palette())
# <ipython-input-17-942c5080b9b8>:2: UserWarning:
# The palette list has fewer values (10) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=city_wise_sales_mean.values, y=city_wise_sales_mean.index, palette=sns.color_palette())

# %%
region_wise_discount=round(data.groupby('Region')['Discount'].mean(),2)
region_wise_discount
# Out:
# Region
# Central    0.23
# East       0.23
# North      0.12
# South      0.23
# West       0.22
# Name: Discount, dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=region_wise_discount.index, y=region_wise_discount.values, palette=sns.color_palette())
plt.title("Region wise Discount Mean")
plt.ylabel("Discount mean")
plt.xlabel("Region")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-19748c92bf5a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_wise_discount.index, y=region_wise_discount.values, palette=sns.color_palette())
# <ipython-input-19-19748c92bf5a>:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.barplot(x=region_wise_discount.index, y=region_wise_discount.values, palette=sns.color_palette())

# %%
data.head()
# Out:
#   Order ID Customer Name          Category      Sub Category         City  \
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1  11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2  06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3  10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4  10-11-2016  South   2355      0.26  918.45  Tamil Nadu

# %%
product_wise_sales_mean=round(data.groupby('Category')['Sales'].mean(),2)
product_wise_sales_mean
# Out:
# Category
# Bakery               1494.89
# Beverages            1489.51
# Eggs, Meat & Fish    1521.75
# Food Grains          1513.07
# Fruits & Veggies     1481.47
# Oil & Masala         1497.75
# Snacks               1477.90
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=product_wise_sales_mean.index, y=product_wise_sales_mean.values, palette=sns.color_palette())
plt.title("Product wise sales Mean")
plt.ylabel("Sales mean")
plt.xlabel("Product")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-12f073d55f6e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_wise_sales_mean.index, y=product_wise_sales_mean.values, palette=sns.color_palette())
# <ipython-input-22-12f073d55f6e>:2: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   sns.barplot(x=product_wise_sales_mean.index, y=product_wise_sales_mean.values, palette=sns.color_palette())

# %%
product_wise_discount_mean=round(data.groupby('Category')['Discount'].mean(),2)
product_wise_discount_mean
# Out:
# Category
# Bakery               0.23
# Beverages            0.23
# Eggs, Meat & Fish    0.23
# Food Grains          0.23
# Fruits & Veggies     0.23
# Oil & Masala         0.22
# Snacks               0.22
# Name: Discount, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.pie(product_wise_discount_mean.values, labels = product_wise_discount_mean.index, autopct='%1.1f%%', startangle=90)
plt.title("Product wise Discount Mean")
plt.show()

# %%
data.head()
# Out:
#   Order ID Customer Name          Category      Sub Category         City  \
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1  11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2  06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3  10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4  10-11-2016  South   2355      0.26  918.45  Tamil Nadu

# %%
print(data['Order Date'].head())
# Out:
# 0    11-08-2017
# 1    11-08-2017
# 2    06-12-2017
# 3    10-11-2016
# 4    10-11-2016
# Name: Order Date, dtype: object

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'], infer_datetime_format=True, errors='coerce')
data['Order Date'] = pd.to_datetime(data['Order Date'], format='%m/%d/%Y', errors='coerce')
data['Order Year'] = data['Order Date'].dt.year
print(data.head())
# Out:
#   Order ID Customer Name          Category      Sub Category         City  \
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#   Order Date Region  Sales  Discount  Profit       State  Order Year
# 0 2017-11-08  North   1254      0.12  401.28  Tamil Nadu      2017.0
# 1 2017-11-08  South    749      0.18  149.80  Tamil Nadu      2017.0
# 2 2017-06-12   West   2360      0.21  165.20  Tamil Nadu      2017.0
# 3 2016-10-11  South    896      0.25   89.60  Tamil Nadu      2016.0
# 4 2016-10-11  South   2355      0.26  918.45  Tamil Nadu      2016.0
# ...

# %%
data.head()
# Out:
#   Order ID Customer Name          Category      Sub Category         City  \
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#   Order Date Region  Sales  Discount  Profit       State  Order Year
# 0 2017-11-08  North   1254      0.12  401.28  Tamil Nadu      2017.0
# 1 2017-11-08  South    749      0.18  149.80  Tamil Nadu      2017.0
# 2 2017-06-12   West   2360      0.21  165.20  Tamil Nadu      2017.0
# 3 2016-10-11  South    896      0.25   89.60  Tamil Nadu      2016.0
# 4 2016-10-11  South   2355      0.26  918.45  Tamil Nadu      2016.0

# %%
Profit_year=round(data.groupby('Order Year')['Profit'].sum(),2)
Profit_year
# Out:
# Order Year
# 2015.0    296603.58
# 2016.0    312507.17
# 2017.0    392920.64
# 2018.0    501027.64
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.pie(Profit_year.values, labels = Profit_year.index, autopct='%1.1f%%', startangle=90)
plt.title("Profit Year")
plt.show()
